# %%
from transformers import Wav2Vec2ForCTC, Wav2Vec2Processor, Wav2Vec2ForCTC
import torch
import librosa
import yt_dlp
import textwrap

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
url = 'https://www.youtube.com/watch?v=7KrOXIq5BtM'

ydl_opts = {
    'format': 'bestaudio/best',
    'postprocessors': [{
        'key': 'FFmpegExtractAudio',
        'preferredcodec': 'mp3',
        'preferredquality': '192',
    }],
    'outtmpl': 'audio.%(ext)s'
}

with yt_dlp.YoutubeDL(ydl_opts) as ydl:
    ydl.download([url])
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=7KrOXIq5BtM
# [youtube] 7KrOXIq5BtM: Downloading webpage
# [youtube] 7KrOXIq5BtM: Downloading ios player API JSON
# [youtube] 7KrOXIq5BtM: Downloading mweb player API JSON
# [youtube] 7KrOXIq5BtM: Downloading m3u8 information
# [info] 7KrOXIq5BtM: Downloading 1 format(s): 251
# [download] Destination: audio.webm
# [download] 100% of    8.55MiB in 00:00:00 at 19.05MiB/s
# [ExtractAudio] Destination: audio.mp3
# Deleting original file audio.webm (pass -k to keep)

# %%
model = Wav2Vec2ForCTC.from_pretrained(
    'facebook/wav2vec2-large-robust-ft-libri-960h', 
    torch_dtype=torch.float16
    ).to(device)

processor = Wav2Vec2Processor.from_pretrained('facebook/wav2vec2-large-robust-ft-libri-960h')

# %%
cc = ''

input_audio, _ = librosa.load('audio.mp3', sr=16000)
input_values = processor(input_audio, return_tensors="pt", padding="longest", sampling_rate=16000).input_values.to(torch.float16).to(device)

with torch.no_grad():
    logits = model(input_values).logits
    predicted_ids = torch.argmax(logits, dim=-1)
    
transcription = processor.batch_decode(predicted_ids)[0]
cc += transcription 
cc += ' '

# %%
wrapped_text = textwrap.fill(cc, width=150)
print(wrapped_text)
# Out:
# NEW MODERN AGE TEASES CIVILISATIONS SEVAN GAMEPLAY INSITS IS WELLIS SOME BEG NEW LEADS AND SERVES IT'S TIME TO JUMP INTO CIV SEVEN SO WELCOM TO THE
# MODERN AGE OR A TEASER FOR IT AT LEAST OF COURSE WE HAVE SEEN SOME STUFF ALREADY HERE AND THERE JUST LITTLE GLIMPSES OF THE MODERN AGE IN THOSE
# INITIAL TRAILERS IN A NEW SHORT JUST RE LEASED A DAY OR TWO AGO THEY TALK A LITTLE BIT ABOUT THE EXPLORATION AGE AND HOW THAT LEANSIN TO THE MODERN
# THIS MEANS YOU'R GING T ONT TO BE SAILING UP NAVIGABLE RIVERS WHERE YOU CAN PILLAGE RED AS WELL AS CAPTURE SETTLEMENTS BUILT OFF OF THESE RIVERS S
# OBVIOUSLY THEY START BY TALKING ABOUT NAVEI ABLE RIVERS A GREAT AD ITION TO SYFSEVEN THE CRUSIWALL PAT HERE IN THIS GAME PLA IS THAT YOU CAN CAPTURE
